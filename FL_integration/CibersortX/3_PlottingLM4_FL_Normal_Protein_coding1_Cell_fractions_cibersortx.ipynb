# %%
import pandas as pd 
#input fraction file obtained from CibersortX analysis on FL+ NORMAL COHORT FOR BETTER IMPUTATION OF THE B CELL DATA
#df = pd.read_csv(r'/Users/ankushs/Dropbox (UiO)/LymphomaBiology/FL1/FL1_RNASEQ/1_1_CIBERSORTX/CIBERSORTX_SALMON/CIbersortX_local_Hires/LM8_FL_NORMAL_CIBERSORTX_PROTEIN_CODING/CIBERSORTxGEP_LM8_protein_coding_fl_Normal_Fractions.txt',sep='\t')
df = pd.read_csv(r'/Users/ankushs/Dropbox (UiO)/LymphomaBiology/FL1/FL1_RNASEQ/1_1_CIBERSORTX/CIBERSORTX_SALMON/CIbersortX_local_Hires/LM4_FL_NORMAL_PROTEIN_CODING/CIBERSORTxGEP_LM4_protein_coding_fl_Normal_Fractions.txt',sep='\t')

#df = df[df['Mixture'].isin(['P1_1','P1_2','P2_1','P2_2','P4_1','P6_3','P8_2','P9_2','P10_2','P11_2','P12_1','P14_1','P14_2','P23_1','P27_1','P27_2','P28_1','P29_1','P29_2','P30_2','P31_1','P31_4','P33_1','P34_2','P35_2','P36_2','P40_1','P41_1','P42_1','P42_2','P43_1','P44_1','P44_2','P46_1','P46_3','P48_1','P49_1','P49_2','P50_1','P56_1','P56_2','P75_1','P11_1','P9_1','P3_1','P3_2','P46_2','P6_2','P57_1','P58_1','P10_1','P21_1','P21_2','P23_2','P23_3','P25_2','P27_3','P31_3','P32_1','P43_2','P59_1','P61_1','P75_2','P75_3'])]

df["Mixture"].replace({"BC1_Stim" :"PBMC 1, stim II","BC1_Unstim" :"PBMC 1, stim I","BC2_Stim" :"PBMC 2, stim II","BC2_Unstim" :"PBMC 2, stim I","BC3_Stim" :"PBMC 3, stim II","BC3_Unstim" :"PBMC 3, stim I","BC4_Stim" :"PBMC 4, stim II","BC4_Unstim" :"PBMC 4, stim I","T25ii_GC" :"Tonsil 25, GC BC","T25ii_Memory" :"Tonsil 25, memory BC","T25ii_Naive" :"Tonsil 25, naive BC","T31_GC" :"Tonsil 31, GC BC","T31_Memory" :"Tonsil 31, memory BC","T31_Naive" :"Tonsil 31, naive BC","T7_GC" :"Tonsil 7, GC BC","T7_Memory" :"Tonsil 7, memory BC","T7_Naive" :"Tonsil 7, naive BC","T9_GC" :"Tonsil 9, GC BC","T9_Memory" :"Tonsil 9, memory BC","T9_Naive" :"Tonsil 9, naive BC"}, inplace=True)
df["Mixture"].replace({"P1_1" :"P1-1","P1_2" :"P1-2","P2_1" :"P2-1","P2_2" :"P2-2","P4_1" :"P4-1","P6_3" :"P6-3","P8_2" :"P8-2","P9_2" :"P9-2","P10_2" :"P10-2","P11_2" :"P11-2","P12_1" :"P12-1","P14_1" :"P14-1","P14_2" :"P14-2","P23_1" :"P23-1","P27_1" :"P27-1","P27_2" :"P27-2","P28_1" :"P28-1","P29_1" :"P29-1","P29_2" :"P29-2","P30_2" :"P30-2","P31_1" :"P31-1","P31_4" :"P31-4","P33_1" :"P33-1","P34_2" :"P34-2","P35_2" :"P35-2","P36_2" :"P36-2","P40_1" :"P40-1","P41_1" :"P41-1","P42_1" :"P42-1","P42_2" :"P42-2","P43_1" :"P43-1","P44_1" :"P44-1","P44_2" :"P44-2","P46_1" :"P46-1","P46_3" :"P46-3","P48_1" :"P48-1","P49_1" :"P49-1","P49_2" :"P49-2","P50_1" :"P50-1","P56_1" :"P56-1","P56_2" :"P56-2","P75_1" :"P75-1","P11_1" :"P11-1","P9_1" :"P9-1","P3_1" :"P3-1","P3_2" :"P3-2","P46_2" :"P46-2","P6_2" :"P6-2","P57_1" :"P57-1","P58_1" :"P58-1","P10_1" :"P10-1","P21_1" :"P21-1","P21_2" :"P21-2","P23_2" :"P23-2","P23_3" :"P23-3","P25_2" :"P25-2","P27_3" :"P27-3","P31_3" :"P31-3","P32_1" :"P32-1","P43_2" :"P43-2","P59_1" :"P59-1","P61_1" :"P61-1","P75_2" :"P75-2","P75_3" :"P75-3"}, inplace=True)
df
# Out:
#                 Mixture  B cells naive  B cells memory  Plasma cells  \
# 0                  P1-1       0.341726        0.284325      0.086615
# 1                  P1-2       0.127105        0.322897      0.038430
# 2                  P2-1       0.290996        0.096812      0.003120
# 3                  P2-2       0.528746        0.026304      0.012591
# 4                  P4-1       0.334432        0.236155      0.009134
# ..                  ...            ...             ...           ...
# 82  Tonsil 7, memory BC       0.000000        0.935196      0.019040
# 83   Tonsil 7, naive BC       0.554980        0.265997      0.000000
# 84      Tonsil 9, GC BC       0.303257        0.469191      0.205991
# 85  Tonsil 9, memory BC       0.064379        0.880910      0.027722
# 86   Tonsil 9, naive BC       0.532508        0.391461      0.026280
#
#     T cells CD8  T cells CD4 naive  T cells CD4 memory resting  \
# 0      0.034298           0.005395                    0.074491
# ...

# %%
#df.columns = ['Mixture','B cells','B cells','Plasma cells','T cells CD8','T cells CD4','T cells CD4','T cells CD4','T cells follicular helper','T cells regulatory (Tregs)','NK cells','NK cells','Monocytes Macrophages','Monocytes Macrophages','Monocytes Macrophages','Monocytes Macrophages','Dendritic cells','Dendritic cells','Remaining','Remaining','Remaining','Remaining','Remaining','P-value','Correlation','RMSE']
##LM8Signatures merged from LM22 signatures 
#df.columns = ['Mixture','B cells','B cells','Plasma cells','T cells CD8','T cells CD4','T cells CD4','T cells CD4','T cells CD4','T cells CD4','NK cells','NK cells','Monocytes Macrophages','Monocytes Macrophages','Monocytes Macrophages','Monocytes Macrophages','Dendritic cells','Dendritic cells','Eosinophils|Neutrophils|Mast cells','Eosinophils|Neutrophils|Mast cells','Eosinophils|Neutrophils|Mast cells','Eosinophils|Neutrophils|Mast cells','Eosinophils|Neutrophils|Mast cells','P-value','Correlation','RMSE']
##LM4Signatures merged from LM22 signatures 
#df.columns = ['Mixture','B cells','B cells','Plasma cells','T cells CD8','T cells CD4','T cells CD4','T cells CD4','T cells CD4','T cells CD4','NK cells','NK cells','Monocytes Macrophages','Monocytes Macrophages','Monocytes Macrophages','Monocytes Macrophages','Dendritic cells','Dendritic cells','Eosinophils|Neutrophils|Mast cells','Eosinophils|Neutrophils|Mast cells','Eosinophils|Neutrophils|Mast cells','Eosinophils|Neutrophils|Mast cells','Eosinophils|Neutrophils|Mast cells','P-value','Correlation','RMSE']
df.columns = ['Mixture','B cells','B cells','Other cell types','T cells','T cells','T cells','T cells','T cells','T cells','NK cells','NK cells','Other cell types','Other cell types','Other cell types','Other cell types','Other cell types','Other cell types','Other cell types','Other cell types','Other cell types','Other cell types','Other cell types','P-value','Correlation','RMSE']

#original order
#'B cells','B cells','Remaining','T cells','T cells','T cells','T cells','T cells','T cells','Remaining','NK cells','NK cells','Remaining','Remaining','Remaining','Remaining','Remaining','Remaining','Remaining','Remaining','Remaining','Remaining'
df = df.drop(columns=['P-value','Correlation','RMSE'])
df
df1=df.groupby(level=0, axis=1).sum()
df1

df1_temp = df1[df1['Mixture'].isin(["Tonsil 25, GC BC","Tonsil 25, memory BC","Tonsil 25, naive BC","Tonsil 31, GC BC","Tonsil 31, memory BC","Tonsil 31, naive BC","Tonsil 7, GC BC","Tonsil 7, memory BC","Tonsil 7, naive BC","Tonsil 9, GC BC","Tonsil 9, memory BC","Tonsil 9, naive BC","I"])]

#df1_temp = df1[df1['Mixture'].isin(["PBMC 1, stim II","PBMC 1, stim I","PBMC 2, stim II","PBMC 2, stim I","PBMC 3, stim II","PBMC 3, stim I","PBMC 4, stim II","PBMC 4, stim I","Tonsil 25, GC BC","Tonsil 25, memory BC","Tonsil 25, naive BC","Tonsil 31, GC BC","Tonsil 31, memory BC","Tonsil 31, naive BC","Tonsil 7, GC BC","Tonsil 7, memory BC","Tonsil 7, naive BC","Tonsil 9, GC BC","Tonsil 9, memory BC","Tonsil 9, naive BC","I"])]
df2_temp = df1[df1['Mixture'].isin(['P1-1','P1-2','P2-1','P2-2','P4-1','P6-3','P8-2','P9-2','P10-2','P11-2','P12-1','P14-1','P14-2','P23-1','P27-1','P27-2','P28-1','P29-1','P29-2','P30-2','P31-1','P31-4','P33-1','P34-2','P35-2','P36-2','P40-1','P41-1','P42-1','P42-2','P43-1','P44-1','P44-2','P46-1','P46-3','P48-1','P49-1','P49-2','P50-1','P56-1','P56-2','P75-1','P11-1','P9-1','P3-1','P3-2','P46-2','P6-2','P57-1','P58-1','P10-1','P21-1','P21-2','P23-2','P23-3','P25-2','P27-3','P31-3','P32-1','P43-2','P59-1','P61-1','P75-2','P75-3'])]

df1_temp =df1_temp.sort_values(by=['B cells'], ascending=False)
df2_temp =df2_temp.sort_values(by=['B cells'], ascending=False)

#df2 = pd.concat([df1_temp,df2_temp])
#df2 = df1.sort_values(by=['B cells'], ascending=True).sort_index()
#df2
#df2.to_csv('/Users/ankushs/Dropbox (UiO)/LymphomaBiology/FL1/FL1_RNASEQ/0_INPUTFILES/2.DOWNSTREAM_INPUT/Cibersortx/SortedFractionsMerged_LM4Signatures_fl_normal_cohort.csv',sep='\t',index=True)

# %%
df1_temp.loc[len(df1_temp)] = 0
#df1_temp = df1_temp.append(df1_temp, ignore_index=False)
df1_temp["Mixture"].replace({0 :"|"}, inplace=True)
df1_temp
# Out:
#      B cells               Mixture  NK cells  Other cell types   T cells
# 85  0.945289   Tonsil 9, memory BC  0.005209          0.043029  0.006474
# 79  0.939891  Tonsil 31, memory BC  0.002411          0.031576  0.026122
# 82  0.935196   Tonsil 7, memory BC  0.000536          0.038567  0.025700
# 86  0.923969    Tonsil 9, naive BC  0.000000          0.054341  0.021690
# 76  0.860597  Tonsil 25, memory BC  0.017959          0.022904  0.098540
# 80  0.831508   Tonsil 31, naive BC  0.034483          0.025599  0.108410
# 81  0.823634       Tonsil 7, GC BC  0.003100          0.156100  0.017166
# 83  0.820977    Tonsil 7, naive BC  0.003458          0.056812  0.118753
# 77  0.791892   Tonsil 25, naive BC  0.055180          0.023453  0.129475
# 84  0.772448       Tonsil 9, GC BC  0.000000          0.213123  0.014429
# 75  0.715586      Tonsil 25, GC BC  0.000000          0.155307  0.129106
# 78  0.662109      Tonsil 31, GC BC  0.000000          0.283717  0.054174
# ...

# %%
df2 = pd.concat([df1_temp,df2_temp])
#df2=df1_temp

# %%
df3 = df2.set_index('Mixture').T
df3
#df3.to_csv('/Users/ankushs/Dropbox (UiO)/LymphomaBiology/FL1/FL1_RNASEQ/0_INPUTFILES/2.DOWNSTREAM_INPUT/Cibersortx/Cibersortx_lm4_fractions_proteincoding_tumorpurity_fl_normal_cohort_rowname_celltype.csv',sep='\t',index=True)
# Out:
# Mixture           Tonsil 9, memory BC  Tonsil 31, memory BC  \
# B cells                      0.945289              0.939891
# NK cells                     0.005209              0.002411
# Other cell types             0.043029              0.031576
# T cells                      0.006474              0.026122
#
# Mixture           Tonsil 7, memory BC  Tonsil 9, naive BC  \
# B cells                      0.935196            0.923969
# NK cells                     0.000536            0.000000
# Other cell types             0.038567            0.054341
# T cells                      0.025700            0.021690
#
# Mixture           Tonsil 25, memory BC  Tonsil 31, naive BC  Tonsil 7, GC BC  \
# B cells                       0.860597             0.831508         0.823634
# NK cells                      0.017959             0.034483         0.003100
# Other cell types              0.022904             0.025599         0.156100
# ...

# %%
#plotting and saving results
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt1
import pylab as plt
import matplotlib

####Setting up figure size
SMALL_SIZE = 8
MEDIUM_SIZE = 10
BIGGER_SIZE = 12

plt1.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt1.rc('axes', titlesize=MEDIUM_SIZE)     # fontsize of the axes title
plt1.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt1.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt1.rc('ytick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt1.rc('legend', fontsize=MEDIUM_SIZE)    # legend fontsize
plt1.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title
plt1.rc('axes', linewidth=0.01)
####

sns.set_style("ticks", {"xtick.major.size": 20, "ytick.major.size": 20})
a4_dims = (11.87, 5.5)
colors = ["#4DBBD599","#8175AA","#EABE94","#F59899"]
#colors = ["#91D1C299","#E64B3599",,"#B09C8599"]


#4DBBD599
#91D1C299
#B09C8599
#E64B3599
pal = sns.set_palette(sns.color_palette(colors))
sns.set_context("paper", font_scale=0.8) 
#widths = [2,3]

P=df3.T
P.plot(kind='bar',color=pal,edgecolor=(0,0,0),linewidth=0.2,stacked=True,width=1,figsize=a4_dims)

plt1.xlabel("Sample Name",fontsize=14)
plt1.ylabel("Cibersort imputed fractions",fontsize=14)
matplotlib.rc('axes',labelsize=MEDIUM_SIZE)

matplotlib.rc('axes',linewidth=0.001)
#sns.despine(left=True, bottom=True)

plt.xticks(rotation = 90, ha = 'center')
plt.tight_layout()
legend = plt.legend(bbox_to_anchor = (0.0, 0),ncol = 1,loc='lower left')
frame = legend.get_frame()
frame.set_facecolor('white')
#plt.savefig('FL_Normal_cohort_LM8_cibersortx_imputed_Cellfractions_ordered_protein_coding_20210512_paired_color.pdf')
plt.savefig('__ordered_withoutpbmcs_FL_Normal_cohort_LM4_cibersortx_imputed_Cellfractions_ordered_protein_coding_20210809_bottomleft.pdf')

# %%
df4 = df3.T
df4.to_csv('/Users/ankushs/Dropbox (UiO)/LymphomaBiology/FL1/FL1_RNASEQ/0_INPUTFILES/2.DOWNSTREAM_INPUT/Cibersortx/Cibersortx_lm4_fractions_proteincoding_tumorpurity_fl_Normal_cohort_tonsilsonly.csv',sep='\t',index=True)
df4
# Out:
#                        B cells  NK cells  Other cell types   T cells
# Mixture
# Tonsil 9, memory BC   0.945289  0.005209          0.043029  0.006474
# Tonsil 31, memory BC  0.939891  0.002411          0.031576  0.026122
# Tonsil 7, memory BC   0.935196  0.000536          0.038567  0.025700
# Tonsil 9, naive BC    0.923969  0.000000          0.054341  0.021690
# Tonsil 25, memory BC  0.860597  0.017959          0.022904  0.098540
# ...                        ...       ...               ...       ...
# P44-2                 0.280145  0.047512          0.158050  0.514293
# P3-2                  0.271000  0.002265          0.328202  0.398533
# P25-2                 0.249655  0.046739          0.316321  0.387285
# P42-2                 0.214638  0.068061          0.291852  0.425449
# P41-1                 0.180325  0.030219          0.377047  0.412408
#
# [77 rows x 4 columns]

# %%
###FL_NORMAL:LM10
#df = pd.read_csv(r'/Users/ankushs/Dropbox (UiO)/LymphomaBiology/FL1/FL1_RNASEQ/1_1_CIBERSORTX/CIBERSORTX_SALMON/CIbersortX_local_Hires/LM8_FL_NORMAL_CIBERSORTX_PROTEIN_CODING/CIBERSORTxGEP_LM8_protein_coding_fl_Normal_Fractions.txt',sep='\t')
#df

#df.columns = ['Mixture','B cells','B cells','Plasma cells','T cells CD8','T cells CD4','T cells CD4','T cells CD4','T cells follicular helper','T cells regulatory (Tregs)','NK cells','NK cells','Monocytes Macrophages','Monocytes Macrophages','Monocytes Macrophages','Monocytes Macrophages','Dendritic cells','Dendritic cells','Eosinophils|Neutrophils|Mast cells','Eosinophils|Neutrophils|Mast cells','Eosinophils|Neutrophils|Mast cells','Eosinophils|Neutrophils|Mast cells','Eosinophils|Neutrophils|Mast cells','P-value','Correlation','RMSE']

#df = df.drop(columns=['P-value','Correlation','RMSE'])
#df1=df.groupby(level=0, axis=1).sum()
#df2 = df1.sort_values(by=['B cells', 'T cells CD4'], ascending=False)


#df3 = df2.set_index('Mixture').T

# %%
import seaborn as sns

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt1
import pylab as plt
#sns.set()
#sns.set_style("white")
#plt.figure(figsize=(15, 25))
#pal = sns.color_palette("Paired")
#sns.set_context("paper", font_scale=0.4) 
#widths = [1,5]
#df3.T.plot(kind='bar',color=pal,edgecolor=(0,0,0),linewidth=0.5,stacked=True,width=.9)

#legend = plt.legend(bbox_to_anchor = (0.5, 1.1), loc='upper center',ncol = 8)
#frame = legend.get_frame()
#frame.set_facecolor('white')

#plt.savefig('FL_Normal_LM10_cibersortx_Cellfractions_protein_coding_20210512.pdf')

# %%
#df4 = df3.T
#df4.to_csv('/Users/ankushs/Dropbox (UiO)/LymphomaBiology/FL1/FL1_RNASEQ/0_INPUTFILES/2.DOWNSTREAM_INPUT/Cibersortx_lm10_fractions_proteincoding_tumorpurity.csv',sep='\t',index=True)
